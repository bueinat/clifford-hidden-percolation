# %%
from IPython.display import display, HTML
import help_functions

# %%
display(HTML("""
<style>
.output-wrap pre {
    white-space: pre-wrap;
    word-break: break-word;
}
</style>
"""))
# Out:
# <style>
# .output-wrap pre {
#     white-space: pre-wrap;
#     word-break: break-word;
# }
# </style>

# %%
display(help_functions.create_parameter_widget())
